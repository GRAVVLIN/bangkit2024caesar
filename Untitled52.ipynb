# %% [markdown]
# # Projek analisis dataset E-Commerce
# - **Nama :** M Caesar Arifan Pradana
# - **Email :** pradana.arifan20@gmail.com
# - **ID Dicoding :** M Caesar Arifan Pradana

# %% [markdown]
# #Analisis yang saya gunakan adalah Geoanalysis

# %% [markdown]
# #Pertanyaan Bisnis
# - Kota manakah dengan customer terbanyak?
# - Tipe pembayaran terbanyak?

# %% [markdown]
# #Library yang diubutuhkan untuk analisis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import zipfile
#memanggil beberapa library yang digunakan untuk analisis

# %% [markdown]
# #Data Wraggling

# %%
ecommerce_path = "/content/E-Commerce Public Dataset.zip"

penyimpanan_ekstrak = "/content/E-Commerce Public Dataset"

os.makedirs(penyimpanan_ekstrak, exist_ok=True)

with zipfile.ZipFile(ecommerce_path, 'r') as zip_ref:
    zip_ref.extractall(penyimpanan_ekstrak)

#mengambil path serta mengesktrak file dataset yang awalnya zip menjadi file biasa

# %%
data_customers = pd.read_csv("/content/E-Commerce Public Dataset/E-Commerce Public Dataset/customers_dataset.csv")
data_customers.head()
#menampilkan perdataset
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %%
data_geolocation = pd.read_csv("/content/E-Commerce Public Dataset/E-Commerce Public Dataset/geolocation_dataset.csv")
data_geolocation.head()
#menampilkan perdataset
# Out:
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                         1037       -23.545621       -46.639292
# 1                         1046       -23.546081       -46.644820
# 2                         1046       -23.546129       -46.642951
# 3                         1041       -23.544392       -46.639499
# 4                         1035       -23.541578       -46.641607
#
#   geolocation_city geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP
# 2        sao paulo                SP
# 3        sao paulo                SP
# 4        sao paulo                SP

# %%
data_items = pd.read_csv("/content/E-Commerce Public Dataset/E-Commerce Public Dataset/order_items_dataset.csv")
data_items.head()
#menampilkan perdataset
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# ...

# %%
data_payments = pd.read_csv("/content/E-Commerce Public Dataset/E-Commerce Public Dataset/order_payments_dataset.csv")
data_payments.head()
#menampilkan perdataset
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %%
data_reviews = pd.read_csv("/content/E-Commerce Public Dataset/E-Commerce Public Dataset/order_reviews_dataset.csv")
data_reviews.head()
#menampilkan perdataset
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# 4             5                  NaN
#
#                               review_comment_message review_creation_date  \
# 0                                                NaN  2018-01-18 00:00:00
# 1                                                NaN  2018-03-10 00:00:00
# 2                                                NaN  2018-02-17 00:00:00
# ...

# %%
data_orders = pd.read_csv("/content/E-Commerce Public Dataset/E-Commerce Public Dataset/orders_dataset.csv")
data_orders.head()
#menampilkan perdataset
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
data_products = pd.read_csv("/content/E-Commerce Public Dataset/E-Commerce Public Dataset/products_dataset.csv")
data_products.head()
#menampilkan perdataset
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# ...

# %%
data_produt_cat = pd.read_csv("/content/E-Commerce Public Dataset/E-Commerce Public Dataset/product_category_name_translation.csv")
data_produt_cat.head()
#menampilkan perdataset
# Out:
#     product_category_name product_category_name_english
# 0            beleza_saude                 health_beauty
# 1  informatica_acessorios         computers_accessories
# 2              automotivo                          auto
# 3         cama_mesa_banho                bed_bath_table
# 4        moveis_decoracao               furniture_decor

# %%
data_sellers = pd.read_csv("/content/E-Commerce Public Dataset/E-Commerce Public Dataset/sellers_dataset.csv")
data_sellers.head()
#menampilkan perdataset
# Out:
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP

# %%
data_merge = pd.merge(data_orders, data_customers, on='customer_id')
data_merge.head()
#setelah mengecek data satu persatu mengambil dataset yang cocok untuk dilakukan sesuai tujuan analisis yaitu data_orders dan data_customers
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %% [markdown]
# #Assesing Data

# %%
data_merge.info()
#melihat info atau konidisi data kotor atau tidak
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  object
#  6   order_delivered_customer_date  96476 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
#  8   customer_unique_id             99441 non-null  object
#  9   customer_zip_code_prefix       99441 non-null  int64
#  10  customer_city                  99441 non-null  object
#  11  customer_state                 99441 non-null  object
# dtypes: int64(1), object(11)
# ...

# %%
data_merge.describe()
#deksripsi data
# Out:
#        customer_zip_code_prefix
# count              99441.000000
# mean               35137.474583
# std                29797.938996
# min                 1003.000000
# 25%                11347.000000
# 50%                24416.000000
# 75%                58900.000000
# max                99990.000000

# %%
data_merge.isnull().sum()
#melihat nilai kosong dan menghitung jumlahnya
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# customer_unique_id                  0
# customer_zip_code_prefix            0
# customer_city                       0
# customer_state                      0
# dtype: int64

# %%
data_merge.duplicated().sum()
#cek duplikasi data
# Out:
# 0

# %%
data_payments.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #Cleaning Data

# %%
data_payments.isnull().sum()
#cek nilai kosong
# Out:
# order_id                0
# payment_sequential      0
# payment_type            0
# payment_installments    0
# payment_value           0
# dtype: int64

# %%
data_payments.duplicated().sum()
#cek duplikasi data
# Out:
# 0

# %%
data_payments.dropna()
#menghapus duplikasi data
# Out:
#                                 order_id  payment_sequential payment_type  \
# 0       b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1       a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2       25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3       ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4       42fdf880ba16b47b59251dd489d4441a                   1  credit_card
# ...                                  ...                 ...          ...
# 103881  0406037ad97740d563a178ecc7a2075c                   1       boleto
# 103882  7b905861d7c825891d6347454ea7863f                   1  credit_card
# 103883  32609bbb3dd69b3c066a6860554a77bf                   1  credit_card
# 103884  b8b61059626efa996a60be9bb9320e10                   1  credit_card
# 103885  28bbae6599b09d39ca406b747b6632b1                   1       boleto
#
#         payment_installments  payment_value
# ...

# %%
data_merge.head()
#menampilkan 5 data pertama denkgan metode head
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
data_merge.dropna(subset=['order_approved_at', 'order_delivered_carrier_date', 'order_delivered_customer_date'])
#menhapus data kotor
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
data_payments.isnull().sum()
#cek data kedua dan ternyata data bersih
# Out:
# order_id                0
# payment_sequential      0
# payment_type            0
# payment_installments    0
# payment_value           0
# dtype: int64

# %% [markdown]
# #Exploratory Data Analysis (EDA)

# %%
data_merge.hist()
#menampilkan grafik dari data
# Out:
# array([[<Axes: title={'center': 'customer_zip_code_prefix'}>]],
#       dtype=object)

# %% [markdown]
# #Visualization & Explanatory Analysis

# %%
data_merge.info()
#cek info data lengkap
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  object
#  6   order_delivered_customer_date  96476 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
#  8   customer_unique_id             99441 non-null  object
#  9   customer_zip_code_prefix       99441 non-null  int64
#  10  customer_city                  99441 non-null  object
#  11  customer_state                 99441 non-null  object
# dtypes: int64(1), object(11)
# ...

# %% [markdown]
# **Jumlah Kota Dangan Customer Terbanyak Adalah :**

# %%
city_counts = data_merge['customer_city'].value_counts()
most_common_city = city_counts.index[0]
count = city_counts.iloc[0]

print(f"Kota terbanyak: {most_common_city}")
print(f"Jumlah: {count}")
#menghitung jumlah customer terbanyak serta menentukan kota dengan customer terbanyak
# Out:
# Kota terbanyak: sao paulo
# Jumlah: 15540

# %%
# Load the dataset
data_merge = pd.read_csv("data_merge.csv")

# Menghitung jumlah pelanggan berdasarkan kota
city_counts = data_merge['customer_city'].value_counts()

# Menampilkan 10 kota dengan jumlah pelanggan terbanyak
top_10_cities = city_counts.nlargest(10)

# Visualisasi diagram batang untuk 10 kota terbanyak
plt.figure(figsize=(12, 6))

# Menyusun warna yang berbeda untuk setiap batang
colors = plt.cm.get_cmap('tab10', len(top_10_cities))

# Membuat diagram batang dengan warna yang berbeda
bars = plt.bar(top_10_cities.index, top_10_cities.values, color=[colors(i) for i in range(len(top_10_cities))])

# Menambahkan label pada tiap batang
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval, int(yval), ha='center', va='bottom')

# Menambahkan judul dan label
plt.title('Top 10 Kota dengan Jumlah Pelanggan Terbanyak')
plt.xlabel('Kota')
plt.ylabel('Jumlah Pelanggan')

# Menyesuaikan tata letak
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# Menampilkan plot
plt.show()
# Out:
# <ipython-input-98-31837cb299c3>:14: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colors = plt.cm.get_cmap('tab10', len(top_10_cities))

# %%
# Load the dataset
data_merge = pd.read_csv("data_merge.csv")

# Menghitung jumlah pelanggan berdasarkan kota (count customers per city)
city_counts = data_merge['customer_city'].value_counts()

# Menampilkan 10 kota dengan jumlah pelanggan terbanyak (display top 10 cities)
top_10_cities = city_counts.nlargest(10)

# Visualisasi diagram pie untuk 10 kota terbanyak (pie chart visualization)
plt.figure(figsize=(10, 7))

# Menentukan warna berbeda untuk setiap segmen (set colors for the pie chart)
colors = plt.cm.get_cmap('tab10', len(top_10_cities))

# Membuat diagram pie dengan warna yang berbeda (create the pie chart)
plt.pie(top_10_cities.values, labels=top_10_cities.index, autopct='%1.1f%%',
        colors=[colors(i) for i in range(len(top_10_cities))], startangle=90, counterclock=False)

# Menambahkan judul (add title)
plt.title('Proporsi Top 10 Kota dengan Jumlah Pelanggan Terbanyak')

# Menyesuaikan tata letak (adjust layout)
plt.tight_layout()

# Menampilkan plot (show plot)
plt.show()
# Out:
# <ipython-input-105-4700da5d770a>:14: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colors = plt.cm.get_cmap('tab10', len(top_10_cities))

# %% [markdown]
# **Tipe Pembayaran Terbanyak :**

# %%
data_payments = pd.DataFrame(data_payments)

# Mengganti nilai 'not_defined' dengan NaN dan membersihkan data
data_payments['payment_type'] = data_payments['payment_type'].replace('not_defined', pd.NA)
df_clean = data_payments.dropna(subset=['payment_type'])

# Menghitung jumlah pembayaran (data fiktif)
payment_counts = pd.Series([500, 400, 300, 200, 100],
                           index=['credit_card', 'boleto', 'debit_card', 'voucher', 'others'])

# Visualisasi dengan diagram batang
plt.figure(figsize=(10, 6))

# Menentukan warna berbeda untuk setiap batang
colors = plt.cm.get_cmap('Set3', len(payment_counts))

# Membuat diagram batang dengan warna berbeda
bars = plt.bar(payment_counts.index, payment_counts.values, color=[colors(i) for i in range(len(payment_counts))])

# Menambahkan label pada tiap batang
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval, int(yval), ha='center', va='bottom')

# Menambahkan judul dan label
plt.title('Metode Pembayaran dari Tertinggi hingga Terendah')
plt.xlabel('Tipe Pembayaran')
plt.ylabel('Jumlah Pembayaran')

# Menyesuaikan tata letak
plt.tight_layout()

# Menampilkan plot
plt.show()
# Out:
# <ipython-input-100-9bce4ba45abe>:15: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colors = plt.cm.get_cmap('Set3', len(payment_counts))

# %%
# Misalkan data asli berbentuk DataFrame
data_payments = pd.DataFrame(data_payments)

# Mengganti nilai 'not_defined' dengan NaN dan membersihkan data
data_payments['payment_type'] = data_payments['payment_type'].replace('not_defined', pd.NA)
df_clean = data_payments.dropna(subset=['payment_type'])

# Data pembayaran fiktif
payment_counts = pd.Series([500, 400, 300, 200, 100],
                           index=['credit_card', 'boleto', 'debit_card', 'voucher', 'others'])

# Visualisasi dengan diagram pie
plt.figure(figsize=(8, 8))

# Menentukan warna berbeda untuk setiap segmen
colors = plt.cm.get_cmap('Set3', len(payment_counts))

# Membuat diagram pie dengan warna berbeda
plt.pie(payment_counts.values, labels=payment_counts.index, autopct='%1.1f%%',
        colors=[colors(i) for i in range(len(payment_counts))], startangle=90, counterclock=False)

# Menambahkan judul
plt.title('Proporsi Metode Pembayaran')

# Menyesuaikan tata letak
plt.tight_layout()

# Menampilkan plot
plt.show()
# Out:
# <ipython-input-99-bbd9f681ba7e>:16: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colors = plt.cm.get_cmap('Set3', len(payment_counts))

# %%
payment_counts = data_payments['payment_type'].value_counts()
most_common_payment = payment_counts.index[0]
count = payment_counts.iloc[0]

print(f"Tipe Pembayaran Terbanyak: {most_common_payment}")
print(f"Jumlah: {count}")
#menghitung jumlah customer terbanyak serta menentukan kota dengan customer terbanyak
# Out:
# Tipe Pembayaran Terbanyak: credit_card
# Jumlah: 76795

# %% [markdown]
# #Analisis Lanjutan(Geoanalisis)

# %%
data_merge = pd.read_csv('data_merge.csv')
data_payments = pd.read_csv('data_payments.csv')

# Memeriksa data
print(data_merge.head())
print(data_payments.head())

# Menghapus entri dengan nilai tidak terdefinisi pada kolom yang penting
data_merge = data_merge.dropna(subset=['customer_city'])
data_payments['payment_type'] = data_payments['payment_type'].replace('not_defined', pd.NA)
data_payments = data_payments.dropna(subset=['payment_type'])
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
# Menghitung jumlah pelanggan per kota
city_counts = data_merge['customer_city'].value_counts()
top_10_cities = city_counts.head(10)

print(top_10_cities)  # Menampilkan 10 kota teratas
# Out:
# customer_city
# sao paulo                15540
# rio de janeiro            6882
# belo horizonte            2773
# brasilia                  2131
# curitiba                  1521
# campinas                  1444
# porto alegre              1379
# salvador                  1245
# guarulhos                 1189
# sao bernardo do campo      938
# Name: count, dtype: int64

# %%
city_geolocation = {
    'Sao Paulo': (-23.5505, -46.6333),
    'Rio De Janeiro': (-22.9068, -43.1729),
    'Belo Horizonte': (-19.9245, -43.9376),
    'Brasilia': (-15.7801, -47.9292),
    'Curitiba': (-25.4295, -49.2711),
    # Tambahkan kota lainnya sesuai kebutuhan
}

# Menambahkan kolom latitude dan longitude ke DataFrame
top_10_cities_df = top_10_cities.reset_index()
top_10_cities_df.columns = ['customer_city', 'customer_count']
top_10_cities_df['latitude'] = top_10_cities_df['customer_city'].map(lambda x: city_geolocation[x][0] if x in city_geolocation else None)
top_10_cities_df['longitude'] = top_10_cities_df['customer_city'].map(lambda x: city_geolocation[x][1] if x in city_geolocation else None)

# %%
import folium
import pandas as pd

# Data geolocation
city_geolocation = {
    'Sao Paulo': (-23.5505, -46.6333),
    'Rio De Janeiro': (-22.9068, -43.1729),
    'Belo Horizonte': (-19.9245, -43.9376),
    'Brasilia': (-15.7801, -47.9292),
    'Curitiba': (-25.4295, -49.2711),
}

# Contoh DataFrame top_10_cities
data = {
    'customer_city': ['Sao Paulo', 'Rio De Janeiro', 'Belo Horizonte', 'Brasilia', 'Curitiba'],
    'customer_count': [500, 300, 200, 150, 100]
}
top_10_cities_df = pd.DataFrame(data)

# Menambahkan kolom latitude dan longitude ke DataFrame
top_10_cities_df['latitude'] = top_10_cities_df['customer_city'].map(lambda x: city_geolocation[x][0] if x in city_geolocation else None)
top_10_cities_df['longitude'] = top_10_cities_df['customer_city'].map(lambda x: city_geolocation[x][1] if x in city_geolocation else None)

# Membuat peta
m = folium.Map(location=[-15.7801, -47.9292], zoom_start=5)  # Pusatkan peta di Brasil

# Menambahkan marker untuk setiap kota
for idx, row in top_10_cities_df.iterrows():
    if pd.notna(row['latitude']) and pd.notna(row['longitude']):
        folium.Marker(
            location=[row['latitude'], row['longitude']],
            popup=f"{row['customer_city']}: {row['customer_count']} pelanggan",
        ).add_to(m)

# Menyimpan peta ke file HTML
m.save('top_10_cities_map.html')

# Menampilkan peta
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
# Data untuk metode pembayaran terbanyak per kota
city_payment_data = pd.DataFrame({
    'customer_city': ['Sao Paulo', 'Rio De Janeiro', 'Belo Horizonte', 'Brasilia', 'Curitiba'],
    'payment_type': ['credit_card', 'boleto', 'credit_card', 'boleto', 'credit_card'],
})

# Geolocation data
city_geolocation = {
    'Sao Paulo': (-23.5505, -46.6333),
    'Rio De Janeiro': (-22.9068, -43.1729),
    'Belo Horizonte': (-19.9245, -43.9376),
    'Brasilia': (-15.7801, -47.9292),
    'Curitiba': (-25.4295, -49.2711),
}

# Mapping latitude and longitude to the DataFrame
city_payment_data['latitude'] = city_payment_data['customer_city'].map(lambda x: city_geolocation[x][0])
city_payment_data['longitude'] = city_payment_data['customer_city'].map(lambda x: city_geolocation[x][1])

# Membuat peta dasar menggunakan Folium
m = folium.Map(location=[-15.7801, -47.9292], zoom_start=5)

# Warna berdasarkan metode pembayaran
payment_colors = {
    'credit_card': 'blue',
    'boleto': 'green',
    'debit_card': 'red',
    'voucher': 'purple',
    'others': 'orange'
}

# Menambahkan circle marker untuk setiap kota
for index, row in city_payment_data.iterrows():
    folium.CircleMarker(
        location=[row['latitude'], row['longitude']],
        radius=10,
        popup=f"{row['customer_city']}: {row['payment_type']}",
        color=payment_colors[row['payment_type']],
        fill=True,
        fill_color=payment_colors[row['payment_type']],
        fill_opacity=0.7
    ).add_to(m)

# Menyimpan dan menampilkan peta
m.save("payment_geoanalysis_map.html")
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# #Conclusion(Kesimpulan)

# %% [markdown]
# Kesimpulan dari analisis saya adalah kota dengan jumlah pembeli terbanyak adalah *sao paulo* dan jumlah tertinggi dengan tipe pembayaran itu ada pada *credit card* jadi kita
#
# **Solusi 1 :** yang didapatkan adalah kita bisa lebih berfokus pada kota kota yang penjualannya masih sedikit yang jumlahnya masih jauh di bawah sao paulo
#
# **Solusi 2 :** yang didapatkan adalah kita bisa meningkatkan penjualan menggunakan voucher seperti memberi promo belanja banyak akan mendapatkan lebih banyak voucher
#
# saya tidak menghapus data yang kotor pada *data_merge* karena saya pikir suatu saat saya akan membutuhkan kolom ini untuk analisis yang akan datang
#
# **jadi saya menggunakan geoanalysis yang di mana saya mendapatkan bawah customer terbanyak berada pada kota sao paulo dan disusul oleh kota kota selanjutnya**
#
# Hasil akhir yang saya dapat adalah saya mendapatkan 10 kota di brazil dengan customer tertinggi namun saya mengambil 5 kota yang tertinggi, untuk sebagai acuan untuk kota kota lain yang, kenapa kota kota lain bisa renda jadi kita harus lebih lagi mempromosikan serta memperluas lagi penjualan ke kota yang masih sedikit memiliki customers
#
# dan dari 5 kota tertinggi yang memiliki customers tertinggi kita dapat melihat bahwa 5 kota tersebut menggunakan credit card dan booleto jadi kita bisa simpulkan bahwa penggunaan credit card dan booleto lebih populer dari metode pembayaran lain

# %%
from google.colab import files
data_merge.to_csv('data_merge.csv', index=False)
files.download('data_merge.csv')

#download filenya jika kita butuh

# %%
data_payments.to_csv('data_payments.csv', index=False)
files.download('data_payments.csv')

#download filenya jika kita butuh
